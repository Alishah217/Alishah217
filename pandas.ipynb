# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['Name', 'Sex', 'Cabin', 'Embarked']]
# Out:
#                                                   Name     Sex Cabin Embarked
# 0                              Braund, Mr. Owen Harris    male   NaN        S
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85        C
# 2                                Heikkinen, Miss Laina  female   NaN        S
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123        S
# 4                             Allen, Mr. William Henry    male   NaN        S
# ..                                                 ...     ...   ...      ...
# 886                              Montvila, Rev. Juozas    male   NaN        S
# 887                        Graham, Miss Margaret Edith  female   B42        S
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN        S
# 889                              Behr, Mr. Karl Howell    male  C148        C
# 890                                Dooley, Mr. Patrick    male   NaN        Q
#
# [891 rows x 4 columns]

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes == 'int'
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes == 'float'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
#Slicing
df[['Ticket']][4:16]
# Out:
#        Ticket
# 4      373450
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
df[['Ticket']][4:16:2]
# Out:
#        Ticket
# 4      373450
# 6       17463
# 8      347742
# 10    PP 9549
# 12  A/5. 2151
# 14     350406

# %%
df[['Ticket','Cabin']][4:17:2]
# Out:
#        Ticket Cabin
# 4      373450   NaN
# 6       17463   E46
# 8      347742   NaN
# 10    PP 9549    G6
# 12  A/5. 2151   NaN
# 14     350406   NaN
# 16     382652   NaN

# %%
#New_c0lumn
df['Murshid'] = 2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col  Murshid
# 0        0         A/5 21171   7.2500   NaN        S        2        2
# 1        0          PC 17599  71.2833   C85        C        2        2
# 2        0  STON/O2. 3101282   7.9250   NaN        S        2        2
# 3        0            113803  53.1000  C123        S        2        2
# 4        0            373450   8.0500   NaN        S        2        2
# ..     ...               ...      ...   ...      ...      ...      ...
# 886      0            211536  13.0000   NaN        S        2        2
# 887      0            112053  30.0000   B42        S        2        2
# 888      2        W./C. 6607  23.4500   NaN        S        2        2
# 889      0            111369  30.0000  C148        C        2        2
# 890      0            370376   7.7500   NaN        Q        2        2
#
# [891 rows x 14 columns]

# %%
df.insert(loc = 3, column = 'Food', value = 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0              1         0       3     0
# 1              2         1       1     0
# 2              3         1       3     0
# 3              4         1       1     0
# 4              5         0       3     0
# ..           ...       ...     ...   ...
# 886          887         0       2     0
# 887          888         1       1     0
# 888          889         0       3     0
# 889          890         1       1     0
# 890          891         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col  Murshid
# 0        0         A/5 21171   7.2500   NaN        S        2        2
# 1        0          PC 17599  71.2833   C85        C        2        2
# 2        0  STON/O2. 3101282   7.9250   NaN        S        2        2
# 3        0            113803  53.1000  C123        S        2        2
# 4        0            373450   8.0500   NaN        S        2        2
# ..     ...               ...      ...   ...      ...      ...      ...
# 886      0            211536  13.0000   NaN        S        2        2
# 887      0            112053  30.0000   B42        S        2        2
# 888      2        W./C. 6607  23.4500   NaN        S        2        2
# 889      0            111369  30.0000  C148        C        2        2
# 890      0            370376   7.7500   NaN        Q        2        2
#
# [891 rows x 15 columns]

# %%
df.insert(loc = 6, column = 'Equipments', value = "Oxygen Cylinder")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0              1         0       3     0
# 1              2         1       1     0
# 2              3         1       3     0
# 3              4         1       1     0
# 4              5         0       3     0
# ..           ...       ...     ...   ...
# 886          887         0       2     0
# 887          888         1       1     0
# 888          889         0       3     0
# 889          890         1       1     0
# 890          891         0       3     0
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#           Equipments   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0    Oxygen Cylinder  22.0      1      0         A/5 21171   7.2500   NaN
# 1    Oxygen Cylinder  38.0      1      0          PC 17599  71.2833   C85
# 2    Oxygen Cylinder  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3    Oxygen Cylinder  35.0      1      0            113803  53.1000  C123
# 4    Oxygen Cylinder  35.0      0      0            373450   8.0500   NaN
# ..               ...   ...    ...    ...               ...      ...   ...
# 886  Oxygen Cylinder  27.0      0      0            211536  13.0000   NaN
# 887  Oxygen Cylinder  19.0      0      0            112053  30.0000   B42
# 888  Oxygen Cylinder   NaN      1      2        W./C. 6607  23.4500   NaN
# 889  Oxygen Cylinder  26.0      0      0            111369  30.0000  C148
# 890  Oxygen Cylinder  32.0      0      0            370376   7.7500   NaN
#
#     Embarked  new_col  Murshid
# 0          S        2        2
# 1          C        2        2
# 2          S        2        2
# 3          S        2        2
# 4          S        2        2
# ..       ...      ...      ...
# 886        S        2        2
# 887        S        2        2
# 888        S        2        2
# 889        C        2        2
# 890        Q        2        2
#
# [891 rows x 16 columns]

# %% [markdown]
# #Part 2

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][0:10]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                        Palsson, Master Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
a = df['Name'][0:10]

# %%
a
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                        Palsson, Master Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
l = ['Ali', 'a2','a3','a4','a5','a6','a7','a8','a9','a10']

# %%
pd.Series(a, index = l)
# Out:
# Ali    NaN
# a2     NaN
# a3     NaN
# a4     NaN
# a5     NaN
# a6     NaN
# a7     NaN
# a8     NaN
# a9     NaN
# a10    NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a), index = l)
# Out:
# Ali                              Braund, Mr. Owen Harris
# a2     Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                 Heikkinen, Miss Laina
# a4          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                              Allen, Mr. William Henry
# a6                                      Moran, Mr. James
# a7                               McCarthy, Mr. Timothy J
# a8                         Palsson, Master Gosta Leonard
# a9     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m1 = pd.Series([100,200,300,400,500], index = [1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([100,200,300,400,500], index = [1,2,3,4,5])

# %%
m2
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m3 = pd.concat([m1,m2])

# %%
m3
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    100
# dtype: int64

# %%
m1*m2
# Out:
# 1     10000
# 2     40000
# 3     90000
# 4    160000
# 5    250000
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0              1         0       3     0
# 1              2         1       1     0
# 2              3         1       3     0
# 3              4         1       1     0
# 4              5         0       3     0
# ..           ...       ...     ...   ...
# 886          887         0       2     0
# 887          888         1       1     0
# 888          889         0       3     0
# 889          890         1       1     0
# 890          891         0       3     0
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#           Equipments   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0    Oxygen Cylinder  22.0      1      0         A/5 21171   7.2500   NaN
# 1    Oxygen Cylinder  38.0      1      0          PC 17599  71.2833   C85
# 2    Oxygen Cylinder  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3    Oxygen Cylinder  35.0      1      0            113803  53.1000  C123
# 4    Oxygen Cylinder  35.0      0      0            373450   8.0500   NaN
# ..               ...   ...    ...    ...               ...      ...   ...
# 886  Oxygen Cylinder  27.0      0      0            211536  13.0000   NaN
# 887  Oxygen Cylinder  19.0      0      0            112053  30.0000   B42
# 888  Oxygen Cylinder   NaN      1      2        W./C. 6607  23.4500   NaN
# 889  Oxygen Cylinder  26.0      0      0            111369  30.0000  C148
# 890  Oxygen Cylinder  32.0      0      0            370376   7.7500   NaN
#
#     Embarked  new_col  Murshid
# 0          S        2        2
# 1          C        2        2
# 2          S        2        2
# 3          S        2        2
# 4          S        2        2
# ..       ...      ...      ...
# 886        S        2        2
# 887        S        2        2
# 888        S        2        2
# 889        C        2        2
# 890        Q        2        2
#
# [891 rows x 16 columns]

# %%
df.drop("PassengerId", axis = 1)
# Out:
#      Survived  Pclass  Food  \
# 0           0       3     0
# 1           1       1     0
# 2           1       3     0
# 3           1       1     0
# 4           0       3     0
# ..        ...     ...   ...
# 886         0       2     0
# 887         1       1     0
# 888         0       3     0
# 889         1       1     0
# 890         0       3     0
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#           Equipments   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0    Oxygen Cylinder  22.0      1      0         A/5 21171   7.2500   NaN
# 1    Oxygen Cylinder  38.0      1      0          PC 17599  71.2833   C85
# 2    Oxygen Cylinder  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3    Oxygen Cylinder  35.0      1      0            113803  53.1000  C123
# 4    Oxygen Cylinder  35.0      0      0            373450   8.0500   NaN
# ..               ...   ...    ...    ...               ...      ...   ...
# 886  Oxygen Cylinder  27.0      0      0            211536  13.0000   NaN
# 887  Oxygen Cylinder  19.0      0      0            112053  30.0000   B42
# 888  Oxygen Cylinder   NaN      1      2        W./C. 6607  23.4500   NaN
# 889  Oxygen Cylinder  26.0      0      0            111369  30.0000  C148
# 890  Oxygen Cylinder  32.0      0      0            370376   7.7500   NaN
#
#     Embarked  new_col  Murshid
# 0          S        2        2
# 1          C        2        2
# 2          S        2        2
# 3          S        2        2
# 4          S        2        2
# ..       ...      ...      ...
# 886        S        2        2
# 887        S        2        2
# 888        S        2        2
# 889        C        2        2
# 890        Q        2        2
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     0
# 1            2         1       1     0
# 2            3         1       3     0
# 3            4         1       1     0
# 4            5         0       3     0
#
#                                                 Name     Sex       Equipments  \
# 0                            Braund, Mr. Owen Harris    male  Oxygen Cylinder
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  Oxygen Cylinder
# 2                              Heikkinen, Miss Laina  female  Oxygen Cylinder
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  Oxygen Cylinder
# 4                           Allen, Mr. William Henry    male  Oxygen Cylinder
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S        2
# 1  38.0      1      0          PC 17599  71.2833   C85        C        2
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S        2
# 3  35.0      1      0            113803  53.1000  C123        S        2
# 4  35.0      0      0            373450   8.0500   NaN        S        2
#
#    Murshid
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
df.drop("Survived", axis = 1, inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass  Food  \
# 0              1       3     0
# 1              2       1     0
# 2              3       3     0
# 3              4       1     0
# 4              5       3     0
# ..           ...     ...   ...
# 886          887       2     0
# 887          888       1     0
# 888          889       3     0
# 889          890       1     0
# 890          891       3     0
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#           Equipments   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0    Oxygen Cylinder  22.0      1      0         A/5 21171   7.2500   NaN
# 1    Oxygen Cylinder  38.0      1      0          PC 17599  71.2833   C85
# 2    Oxygen Cylinder  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3    Oxygen Cylinder  35.0      1      0            113803  53.1000  C123
# 4    Oxygen Cylinder  35.0      0      0            373450   8.0500   NaN
# ..               ...   ...    ...    ...               ...      ...   ...
# 886  Oxygen Cylinder  27.0      0      0            211536  13.0000   NaN
# 887  Oxygen Cylinder  19.0      0      0            112053  30.0000   B42
# 888  Oxygen Cylinder   NaN      1      2        W./C. 6607  23.4500   NaN
# 889  Oxygen Cylinder  26.0      0      0            111369  30.0000  C148
# 890  Oxygen Cylinder  32.0      0      0            370376   7.7500   NaN
#
#     Embarked  new_col  Murshid
# 0          S        2        2
# 1          C        2        2
# 2          S        2        2
# 3          S        2        2
# 4          S        2        2
# ..       ...      ...      ...
# 886        S        2        2
# 887        S        2        2
# 888        S        2        2
# 889        C        2        2
# 890        Q        2        2
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    PassengerId  Pclass  Food  \
# 0            1       3     0
# 1            2       1     0
# 2            3       3     0
# 3            4       1     0
# 4            5       3     0
#
#                                                 Name     Sex       Equipments  \
# 0                            Braund, Mr. Owen Harris    male  Oxygen Cylinder
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  Oxygen Cylinder
# 2                              Heikkinen, Miss Laina  female  Oxygen Cylinder
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  Oxygen Cylinder
# 4                           Allen, Mr. William Henry    male  Oxygen Cylinder
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S        2
# 1  38.0      1      0          PC 17599  71.2833   C85        C        2
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S        2
# 3  35.0      1      0            113803  53.1000  C123        S        2
# 4  35.0      0      0            373450   8.0500   NaN        S        2
#
#    Murshid
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
df.drop(3, inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass  Food  \
# 0              1       3     0
# 1              2       1     0
# 2              3       3     0
# 4              5       3     0
# 5              6       3     0
# ..           ...     ...   ...
# 886          887       2     0
# 887          888       1     0
# 888          889       3     0
# 889          890       1     0
# 890          891       3     0
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#           Equipments   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0    Oxygen Cylinder  22.0      1      0         A/5 21171   7.2500   NaN
# 1    Oxygen Cylinder  38.0      1      0          PC 17599  71.2833   C85
# 2    Oxygen Cylinder  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4    Oxygen Cylinder  35.0      0      0            373450   8.0500   NaN
# 5    Oxygen Cylinder   NaN      0      0            330877   8.4583   NaN
# ..               ...   ...    ...    ...               ...      ...   ...
# 886  Oxygen Cylinder  27.0      0      0            211536  13.0000   NaN
# 887  Oxygen Cylinder  19.0      0      0            112053  30.0000   B42
# 888  Oxygen Cylinder   NaN      1      2        W./C. 6607  23.4500   NaN
# 889  Oxygen Cylinder  26.0      0      0            111369  30.0000  C148
# 890  Oxygen Cylinder  32.0      0      0            370376   7.7500   NaN
#
#     Embarked  new_col  Murshid
# 0          S        2        2
# 1          C        2        2
# 2          S        2        2
# 4          S        2        2
# 5          Q        2        2
# ..       ...      ...      ...
# 886        S        2        2
# 887        S        2        2
# 888        S        2        2
# 889        C        2        2
# 890        Q        2        2
#
# [890 rows x 15 columns]

# %%
df.set_index('Name', inplace = True)

# %%
df
# Out:
#                                                     PassengerId  Pclass  Food  \
# Name
# Braund, Mr. Owen Harris                                       1       3     0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1     0
# Heikkinen, Miss Laina                                         3       3     0
# Allen, Mr. William Henry                                      5       3     0
# Moran, Mr. James                                              6       3     0
# ...                                                         ...     ...   ...
# Montvila, Rev. Juozas                                       887       2     0
# Graham, Miss Margaret Edith                                 888       1     0
# Johnston, Miss Catherine Helen "Carrie"                     889       3     0
# Behr, Mr. Karl Howell                                       890       1     0
# Dooley, Mr. Patrick                                         891       3     0
#
#                                                        Sex       Equipments  \
# Name
# Braund, Mr. Owen Harris                               male  Oxygen Cylinder
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  Oxygen Cylinder
# Heikkinen, Miss Laina                               female  Oxygen Cylinder
# Allen, Mr. William Henry                              male  Oxygen Cylinder
# Moran, Mr. James                                      male  Oxygen Cylinder
# ...                                                    ...              ...
# Montvila, Rev. Juozas                                 male  Oxygen Cylinder
# Graham, Miss Margaret Edith                         female  Oxygen Cylinder
# Johnston, Miss Catherine Helen "Carrie"             female  Oxygen Cylinder
# Behr, Mr. Karl Howell                                 male  Oxygen Cylinder
# Dooley, Mr. Patrick                                   male  Oxygen Cylinder
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss Laina                               26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss Margaret Edith                         19.0      0      0
# Johnston, Miss Catherine Helen "Carrie"              NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss Laina                               STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss Margaret Edith                                   112053  30.0000
# Johnston, Miss Catherine Helen "Carrie"                   W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked  new_col  \
# Name
# Braund, Mr. Owen Harris                              NaN        S        2
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C        2
# Heikkinen, Miss Laina                                NaN        S        2
# Allen, Mr. William Henry                             NaN        S        2
# Moran, Mr. James                                     NaN        Q        2
# ...                                                  ...      ...      ...
# Montvila, Rev. Juozas                                NaN        S        2
# Graham, Miss Margaret Edith                          B42        S        2
# Johnston, Miss Catherine Helen "Carrie"              NaN        S        2
# Behr, Mr. Karl Howell                               C148        C        2
# Dooley, Mr. Patrick                                  NaN        Q        2
#
#                                                     Murshid
# Name
# Braund, Mr. Owen Harris                                   2
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        2
# Heikkinen, Miss Laina                                     2
# Allen, Mr. William Henry                                  2
# Moran, Mr. James                                          2
# ...                                                     ...
# Montvila, Rev. Juozas                                     2
# Graham, Miss Margaret Edith                               2
# Johnston, Miss Catherine Helen "Carrie"                   2
# Behr, Mr. Karl Howell                                     2
# Dooley, Mr. Patrick                                       2
#
# [890 rows x 14 columns]

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Pclass  \
# 0                              Braund, Mr. Owen Harris            1       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2       1
# 2                                Heikkinen, Miss Laina            3       3
# 3                             Allen, Mr. William Henry            5       3
# 4                                     Moran, Mr. James            6       3
# ..                                                 ...          ...     ...
# 885                              Montvila, Rev. Juozas          887       2
# 886                        Graham, Miss Margaret Edith          888       1
# 887            Johnston, Miss Catherine Helen "Carrie"          889       3
# 888                              Behr, Mr. Karl Howell          890       1
# 889                                Dooley, Mr. Patrick          891       3
#
#      Food     Sex       Equipments   Age  SibSp  Parch            Ticket  \
# 0       0    male  Oxygen Cylinder  22.0      1      0         A/5 21171
# 1       0  female  Oxygen Cylinder  38.0      1      0          PC 17599
# 2       0  female  Oxygen Cylinder  26.0      0      0  STON/O2. 3101282
# 3       0    male  Oxygen Cylinder  35.0      0      0            373450
# 4       0    male  Oxygen Cylinder   NaN      0      0            330877
# ..    ...     ...              ...   ...    ...    ...               ...
# 885     0    male  Oxygen Cylinder  27.0      0      0            211536
# 886     0  female  Oxygen Cylinder  19.0      0      0            112053
# 887     0  female  Oxygen Cylinder   NaN      1      2        W./C. 6607
# 888     0    male  Oxygen Cylinder  26.0      0      0            111369
# 889     0    male  Oxygen Cylinder  32.0      0      0            370376
#
#         Fare Cabin Embarked  new_col  Murshid
# 0     7.2500   NaN        S        2        2
# 1    71.2833   C85        C        2        2
# 2     7.9250   NaN        S        2        2
# 3     8.0500   NaN        S        2        2
# 4     8.4583   NaN        Q        2        2
# ..       ...   ...      ...      ...      ...
# 885  13.0000   NaN        S        2        2
# 886  30.0000   B42        S        2        2
# 887  23.4500   NaN        S        2        2
# 888  30.0000  C148        C        2        2
# 889   7.7500   NaN        Q        2        2
#
# [890 rows x 15 columns]

# %%
Make dataframe from the dictionary

# %%
d = {"key1" : [1,2,3,4,5],
     "key2" : [6,7,8,9,10],
     "key3" : [11,12,13,14,15]
    }

# %%
print(d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [11, 12, 13, 14, 15]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
df1 = pd.read_csv("taxanomy.csv")
